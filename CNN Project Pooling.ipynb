# %% [markdown]
# # Extra Credit

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import torch
import torchvision
import torchvision.transforms as transforms
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# %% [markdown]
# #### Prepare for Dataset

# %%
transform = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

trainset = torchvision.datasets.CIFAR10(root='./data', train=True,
                                        download=True, transform=transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=4,
                                          shuffle=True, num_workers=2)

testset = torchvision.datasets.CIFAR10(root='./data', train=False,
                                       download=True, transform=transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=4,
                                         shuffle=False, num_workers=2)

classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
# The function to show an image.
def imshow(img):
    img = img / 2 + 0.5     # Unnormalize.
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()

# Get some random training images.
dataiter = iter(trainloader)
images, labels = next(dataiter)
# Show images.
imshow(torchvision.utils.make_grid(images))
# Print labels.
print(' '.join('%5s' % classes[labels[j]] for j in range(4)))
# Out:
# horse  frog plane  ship

# %% [markdown]
# #### Choose a Device

# %%
# If there are GPUs, choose the first one for computing. Otherwise use CPU.
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)  
# If 'cuda:0' is printed, it means GPU is available.
# Out:
# cuda:0

# %% [markdown]
# #### Network Definition

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        ###### Fill the blank here ######
        self.conv1 = nn.Conv2d(3, 8, kernel_size=3, stride=1, padding=1)
        self.bn1 = nn.BatchNorm2d(8)
        self.relu1 = nn.ReLU()
        self.pool1 = nn.MaxPool2d(2, 2)
        self.dropout1 = nn.Dropout2d(0.5)

        self.conv2 = nn.Conv2d(8, 16, kernel_size=3, stride=1, padding=1)
        self.bn2 = nn.BatchNorm2d(16)
        self.relu2 = nn.ReLU()
        self.pool2 = nn.MaxPool2d(2, 2)
        self.dropout2 = nn.Dropout2d(0.5)

        self.conv3 = nn.Conv2d(16, 32, kernel_size=3, stride=1, padding=1)
        self.bn3 = nn.BatchNorm2d(32)
        self.relu3 = nn.ReLU()
        self.pool3 = nn.MaxPool2d(2, 2)
        self.dropout3 = nn.Dropout2d(0.5)


        self.flatten = nn.Flatten()

        self.linear1 = nn.Linear(512, 256)
        self.relu6 = nn.ReLU()
        self.linear2 = nn.Linear(256, 128)
        self.relu7 = nn.ReLU()
        self.linear3 = nn.Linear(128, 64)
        self.relu8 = nn.ReLU()
        self.linear4 = nn.Linear(64, 32)
        self.relu9 = nn.ReLU()
        self.linear5 = nn.Linear(32, 16)
        self.relu10 = nn.ReLU()
        self.linear6 = nn.Linear(16, 10)

        
        
        
        
    def forward(self, x):
        ###### Fill the blank here ######

        x = self.conv1(x)
        x = self.bn1(x)
        x = self.relu1(x)
        x = self.pool1(x)
        x = self.dropout1(x)

        x = self.conv2(x)
        x = self.bn2(x)
        x = self.relu2(x)
        x = self.pool2(x)
        x = self.dropout2(x)

        x = self.conv3(x)
        x = self.bn3(x)
        x = self.relu3(x)
        x = self.pool3(x)
        x = self.dropout3(x)

        x = self.flatten(x)

        x = self.linear1(x)
        x = self.relu6(x)
        x = self.linear2(x)
        x = self.relu7(x)
        x = self.linear3(x)
        x = self.relu8(x)
        x = self.linear4(x)
        x = self.relu9(x)
        x = self.linear5(x)
        x = self.relu10(x)
        x = self.linear6(x)

        
        return x

net = Net()     # Create the network instance.
net.to(device)  # Move the network parameters to the specified device.
# Out:
# Net(
#   (conv1): Conv2d(3, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn1): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu1): ReLU()
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (dropout1): Dropout2d(p=0.5, inplace=False)
#   (conv2): Conv2d(8, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu2): ReLU()
#   (pool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (dropout2): Dropout2d(p=0.5, inplace=False)
#   (conv3): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu3): ReLU()
#   (pool3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (dropout3): Dropout2d(p=0.5, inplace=False)
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (linear1): Linear(in_features=512, out_features=256, bias=True)
#   (relu6): ReLU()
#   (linear2): Linear(in_features=256, out_features=128, bias=True)
#   (relu7): ReLU()
#   (linear3): Linear(in_features=128, out_features=64, bias=True)
#   (relu8): ReLU()
#   (linear4): Linear(in_features=64, out_features=32, bias=True)
#   (relu9): ReLU()
#   (linear5): Linear(in_features=32, out_features=16, bias=True)
#   (relu10): ReLU()
#   (linear6): Linear(in_features=16, out_features=10, bias=True)
# )

# %% [markdown]
# #### Optimizer and Loss Function

# %%
# We use cross-entropy as loss function.
loss_func = nn.CrossEntropyLoss()  
# We use stochastic gradient descent (SGD) as optimizer.
opt = optim.SGD(net.parameters(), lr=0.001, momentum=0.9)

# %% [markdown]
# #### Training Procedure

# %%
avg_losses = []   # Avg. losses.
epochs = 10       # Total epochs.
print_freq = 100  # Print frequency.

for epoch in range(epochs):  # Loop over the dataset multiple times.
    running_loss = 0.0       # Initialize running loss.
    for i, data in enumerate(trainloader, 0):
        # Get the inputs.
        inputs, labels = data
        
        # Move the inputs to the specified device.
        inputs, labels = inputs.to(device), labels.to(device)
        
        # Zero the parameter gradients.
        opt.zero_grad()

        # Forward step.
        outputs = net(inputs)
        loss = loss_func(outputs, labels)
        
        # Backward step.
        loss.backward()
        
        # Optimization step (update the parameters).
        opt.step()

        # Print statistics.
        running_loss += loss.item()
        if i % print_freq == print_freq - 1: # Print every several mini-batches.
            avg_loss = running_loss / print_freq
            print('[epoch: {}, i: {:5d}] avg mini-batch loss: {:.3f}'.format(
                epoch, i, avg_loss))
            avg_losses.append(avg_loss)
            running_loss = 0.0

print('Finished Training.')
# Out:
# [epoch: 0, i:    99] avg mini-batch loss: 2.316
# [epoch: 0, i:   199] avg mini-batch loss: 2.308
# [epoch: 0, i:   299] avg mini-batch loss: 2.305
# [epoch: 0, i:   399] avg mini-batch loss: 2.304
# [epoch: 0, i:   499] avg mini-batch loss: 2.309
# [epoch: 0, i:   599] avg mini-batch loss: 2.308
# [epoch: 0, i:   699] avg mini-batch loss: 2.302
# [epoch: 0, i:   799] avg mini-batch loss: 2.302
# [epoch: 0, i:   899] avg mini-batch loss: 2.300
# [epoch: 0, i:   999] avg mini-batch loss: 2.303
# [epoch: 0, i:  1099] avg mini-batch loss: 2.307
# [epoch: 0, i:  1199] avg mini-batch loss: 2.307
# [epoch: 0, i:  1299] avg mini-batch loss: 2.303
# [epoch: 0, i:  1399] avg mini-batch loss: 2.301
# [epoch: 0, i:  1499] avg mini-batch loss: 2.302
# [epoch: 0, i:  1599] avg mini-batch loss: 2.304
# [epoch: 0, i:  1699] avg mini-batch loss: 2.304
# [epoch: 0, i:  1799] avg mini-batch loss: 2.302
# [epoch: 0, i:  1899] avg mini-batch loss: 2.301
# [epoch: 0, i:  1999] avg mini-batch loss: 2.300
# [epoch: 0, i:  2099] avg mini-batch loss: 2.305
# [epoch: 0, i:  2199] avg mini-batch loss: 2.301
# [epoch: 0, i:  2299] avg mini-batch loss: 2.302
# [epoch: 0, i:  2399] avg mini-batch loss: 2.305
# [epoch: 0, i:  2499] avg mini-batch loss: 2.306
# [epoch: 0, i:  2599] avg mini-batch loss: 2.302
# [epoch: 0, i:  2699] avg mini-batch loss: 2.303
# [epoch: 0, i:  2799] avg mini-batch loss: 2.302
# [epoch: 0, i:  2899] avg mini-batch loss: 2.301
# [epoch: 0, i:  2999] avg mini-batch loss: 2.304
# [epoch: 0, i:  3099] avg mini-batch loss: 2.302
# [epoch: 0, i:  3199] avg mini-batch loss: 2.305
# [epoch: 0, i:  3299] avg mini-batch loss: 2.302
# [epoch: 0, i:  3399] avg mini-batch loss: 2.302
# [epoch: 0, i:  3499] avg mini-batch loss: 2.301
# [epoch: 0, i:  3599] avg mini-batch loss: 2.303
# [epoch: 0, i:  3699] avg mini-batch loss: 2.300
# [epoch: 0, i:  3799] avg mini-batch loss: 2.302
# [epoch: 0, i:  3899] avg mini-batch loss: 2.301
# [epoch: 0, i:  3999] avg mini-batch loss: 2.303
# [epoch: 0, i:  4099] avg mini-batch loss: 2.302
# [epoch: 0, i:  4199] avg mini-batch loss: 2.300
# [epoch: 0, i:  4299] avg mini-batch loss: 2.298
# [epoch: 0, i:  4399] avg mini-batch loss: 2.305
# [epoch: 0, i:  4499] avg mini-batch loss: 2.302
# [epoch: 0, i:  4599] avg mini-batch loss: 2.301
# [epoch: 0, i:  4699] avg mini-batch loss: 2.304
# [epoch: 0, i:  4799] avg mini-batch loss: 2.301
# [epoch: 0, i:  4899] avg mini-batch loss: 2.300
# [epoch: 0, i:  4999] avg mini-batch loss: 2.303
# [epoch: 0, i:  5099] avg mini-batch loss: 2.299
# [epoch: 0, i:  5199] avg mini-batch loss: 2.299
# [epoch: 0, i:  5299] avg mini-batch loss: 2.298
# [epoch: 0, i:  5399] avg mini-batch loss: 2.301
# [epoch: 0, i:  5499] avg mini-batch loss: 2.298
# [epoch: 0, i:  5599] avg mini-batch loss: 2.300
# [epoch: 0, i:  5699] avg mini-batch loss: 2.297
# [epoch: 0, i:  5799] avg mini-batch loss: 2.298
# [epoch: 0, i:  5899] avg mini-batch loss: 2.300
# [epoch: 0, i:  5999] avg mini-batch loss: 2.296
# [epoch: 0, i:  6099] avg mini-batch loss: 2.300
# [epoch: 0, i:  6199] avg mini-batch loss: 2.293
# [epoch: 0, i:  6299] avg mini-batch loss: 2.291
# [epoch: 0, i:  6399] avg mini-batch loss: 2.294
# [epoch: 0, i:  6499] avg mini-batch loss: 2.287
# [epoch: 0, i:  6599] avg mini-batch loss: 2.294
# [epoch: 0, i:  6699] avg mini-batch loss: 2.276
# [epoch: 0, i:  6799] avg mini-batch loss: 2.282
# [epoch: 0, i:  6899] avg mini-batch loss: 2.283
# [epoch: 0, i:  6999] avg mini-batch loss: 2.277
# [epoch: 0, i:  7099] avg mini-batch loss: 2.266
# [epoch: 0, i:  7199] avg mini-batch loss: 2.242
# [epoch: 0, i:  7299] avg mini-batch loss: 2.256
# [epoch: 0, i:  7399] avg mini-batch loss: 2.232
# [epoch: 0, i:  7499] avg mini-batch loss: 2.231
# [epoch: 0, i:  7599] avg mini-batch loss: 2.236
# [epoch: 0, i:  7699] avg mini-batch loss: 2.244
# [epoch: 0, i:  7799] avg mini-batch loss: 2.230
# [epoch: 0, i:  7899] avg mini-batch loss: 2.244
# [epoch: 0, i:  7999] avg mini-batch loss: 2.186
# [epoch: 0, i:  8099] avg mini-batch loss: 2.178
# [epoch: 0, i:  8199] avg mini-batch loss: 2.173
# [epoch: 0, i:  8299] avg mini-batch loss: 2.160
# [epoch: 0, i:  8399] avg mini-batch loss: 2.212
# [epoch: 0, i:  8499] avg mini-batch loss: 2.175
# [epoch: 0, i:  8599] avg mini-batch loss: 2.199
# [epoch: 0, i:  8699] avg mini-batch loss: 2.141
# [epoch: 0, i:  8799] avg mini-batch loss: 2.174
# [epoch: 0, i:  8899] avg mini-batch loss: 2.108
# [epoch: 0, i:  8999] avg mini-batch loss: 2.134
# [epoch: 0, i:  9099] avg mini-batch loss: 2.216
# [epoch: 0, i:  9199] avg mini-batch loss: 2.159
# [epoch: 0, i:  9299] avg mini-batch loss: 2.103
# [epoch: 0, i:  9399] avg mini-batch loss: 2.097
# [epoch: 0, i:  9499] avg mini-batch loss: 2.148
# [epoch: 0, i:  9599] avg mini-batch loss: 2.161
# [epoch: 0, i:  9699] avg mini-batch loss: 2.109
# [epoch: 0, i:  9799] avg mini-batch loss: 2.095
# [epoch: 0, i:  9899] avg mini-batch loss: 2.116
# [epoch: 0, i:  9999] avg mini-batch loss: 2.125
# [epoch: 0, i: 10099] avg mini-batch loss: 2.122
# [epoch: 0, i: 10199] avg mini-batch loss: 2.112
# [epoch: 0, i: 10299] avg mini-batch loss: 2.168
# [epoch: 0, i: 10399] avg mini-batch loss: 2.119
# [epoch: 0, i: 10499] avg mini-batch loss: 2.077
# [epoch: 0, i: 10599] avg mini-batch loss: 2.117
# [epoch: 0, i: 10699] avg mini-batch loss: 2.117
# [epoch: 0, i: 10799] avg mini-batch loss: 2.128
# [epoch: 0, i: 10899] avg mini-batch loss: 2.101
# [epoch: 0, i: 10999] avg mini-batch loss: 2.139
# [epoch: 0, i: 11099] avg mini-batch loss: 2.142
# [epoch: 0, i: 11199] avg mini-batch loss: 2.072
# [epoch: 0, i: 11299] avg mini-batch loss: 2.055
# [epoch: 0, i: 11399] avg mini-batch loss: 2.136
# [epoch: 0, i: 11499] avg mini-batch loss: 2.132
# [epoch: 0, i: 11599] avg mini-batch loss: 2.115
# [epoch: 0, i: 11699] avg mini-batch loss: 2.112
# [epoch: 0, i: 11799] avg mini-batch loss: 2.040
# [epoch: 0, i: 11899] avg mini-batch loss: 2.116
# [epoch: 0, i: 11999] avg mini-batch loss: 2.094
# [epoch: 0, i: 12099] avg mini-batch loss: 2.122
# [epoch: 0, i: 12199] avg mini-batch loss: 2.078
# [epoch: 0, i: 12299] avg mini-batch loss: 2.072
# [epoch: 0, i: 12399] avg mini-batch loss: 2.098
# [epoch: 0, i: 12499] avg mini-batch loss: 2.071
# [epoch: 1, i:    99] avg mini-batch loss: 2.073
# [epoch: 1, i:   199] avg mini-batch loss: 2.064
# [epoch: 1, i:   299] avg mini-batch loss: 2.097
# [epoch: 1, i:   399] avg mini-batch loss: 2.121
# [epoch: 1, i:   499] avg mini-batch loss: 2.056
# [epoch: 1, i:   599] avg mini-batch loss: 2.088
# [epoch: 1, i:   699] avg mini-batch loss: 2.115
# [epoch: 1, i:   799] avg mini-batch loss: 2.070
# [epoch: 1, i:   899] avg mini-batch loss: 2.057
# [epoch: 1, i:   999] avg mini-batch loss: 2.129
# [epoch: 1, i:  1099] avg mini-batch loss: 2.046
# [epoch: 1, i:  1199] avg mini-batch loss: 2.048
# [epoch: 1, i:  1299] avg mini-batch loss: 2.072
# [epoch: 1, i:  1399] avg mini-batch loss: 2.028
# [epoch: 1, i:  1499] avg mini-batch loss: 2.052
# [epoch: 1, i:  1599] avg mini-batch loss: 2.016
# [epoch: 1, i:  1699] avg mini-batch loss: 2.099
# [epoch: 1, i:  1799] avg mini-batch loss: 2.051
# [epoch: 1, i:  1899] avg mini-batch loss: 2.044
# [epoch: 1, i:  1999] avg mini-batch loss: 2.072
# [epoch: 1, i:  2099] avg mini-batch loss: 2.100
# [epoch: 1, i:  2199] avg mini-batch loss: 2.005
# [epoch: 1, i:  2299] avg mini-batch loss: 2.058
# [epoch: 1, i:  2399] avg mini-batch loss: 2.057
# [epoch: 1, i:  2499] avg mini-batch loss: 2.043
# [epoch: 1, i:  2599] avg mini-batch loss: 1.983
# [epoch: 1, i:  2699] avg mini-batch loss: 2.076
# [epoch: 1, i:  2799] avg mini-batch loss: 2.043
# [epoch: 1, i:  2899] avg mini-batch loss: 1.984
# [epoch: 1, i:  2999] avg mini-batch loss: 1.999
# [epoch: 1, i:  3099] avg mini-batch loss: 2.098
# [epoch: 1, i:  3199] avg mini-batch loss: 2.044
# [epoch: 1, i:  3299] avg mini-batch loss: 2.007
# [epoch: 1, i:  3399] avg mini-batch loss: 2.035
# [epoch: 1, i:  3499] avg mini-batch loss: 2.013
# [epoch: 1, i:  3599] avg mini-batch loss: 2.087
# [epoch: 1, i:  3699] avg mini-batch loss: 1.982
# [epoch: 1, i:  3799] avg mini-batch loss: 1.978
# [epoch: 1, i:  3899] avg mini-batch loss: 2.015
# [epoch: 1, i:  3999] avg mini-batch loss: 2.057
# [epoch: 1, i:  4099] avg mini-batch loss: 2.044
# [epoch: 1, i:  4199] avg mini-batch loss: 2.018
# [epoch: 1, i:  4299] avg mini-batch loss: 2.039
# [epoch: 1, i:  4399] avg mini-batch loss: 2.013
# [epoch: 1, i:  4499] avg mini-batch loss: 2.019
# [epoch: 1, i:  4599] avg mini-batch loss: 2.070
# [epoch: 1, i:  4699] avg mini-batch loss: 1.997
# [epoch: 1, i:  4799] avg mini-batch loss: 1.983
# [epoch: 1, i:  4899] avg mini-batch loss: 2.030
# [epoch: 1, i:  4999] avg mini-batch loss: 2.050
# [epoch: 1, i:  5099] avg mini-batch loss: 2.017
# [epoch: 1, i:  5199] avg mini-batch loss: 1.988
# [epoch: 1, i:  5299] avg mini-batch loss: 2.028
# [epoch: 1, i:  5399] avg mini-batch loss: 2.010
# [epoch: 1, i:  5499] avg mini-batch loss: 1.990
# [epoch: 1, i:  5599] avg mini-batch loss: 1.986
# [epoch: 1, i:  5699] avg mini-batch loss: 2.056
# [epoch: 1, i:  5799] avg mini-batch loss: 2.027
# [epoch: 1, i:  5899] avg mini-batch loss: 2.004
# [epoch: 1, i:  5999] avg mini-batch loss: 2.007
# [epoch: 1, i:  6099] avg mini-batch loss: 2.066
# [epoch: 1, i:  6199] avg mini-batch loss: 2.016
# [epoch: 1, i:  6299] avg mini-batch loss: 1.970
# [epoch: 1, i:  6399] avg mini-batch loss: 1.985
# [epoch: 1, i:  6499] avg mini-batch loss: 1.984
# [epoch: 1, i:  6599] avg mini-batch loss: 2.024
# [epoch: 1, i:  6699] avg mini-batch loss: 1.973
# [epoch: 1, i:  6799] avg mini-batch loss: 2.042
# [epoch: 1, i:  6899] avg mini-batch loss: 2.019
# [epoch: 1, i:  6999] avg mini-batch loss: 2.026
# [epoch: 1, i:  7099] avg mini-batch loss: 1.958
# [epoch: 1, i:  7199] avg mini-batch loss: 1.985
# [epoch: 1, i:  7299] avg mini-batch loss: 1.939
# [epoch: 1, i:  7399] avg mini-batch loss: 1.967
# [epoch: 1, i:  7499] avg mini-batch loss: 2.017
# [epoch: 1, i:  7599] avg mini-batch loss: 2.009
# [epoch: 1, i:  7699] avg mini-batch loss: 1.977
# [epoch: 1, i:  7799] avg mini-batch loss: 2.007
# [epoch: 1, i:  7899] avg mini-batch loss: 1.970
# [epoch: 1, i:  7999] avg mini-batch loss: 1.953
# [epoch: 1, i:  8099] avg mini-batch loss: 1.967
# [epoch: 1, i:  8199] avg mini-batch loss: 1.960
# [epoch: 1, i:  8299] avg mini-batch loss: 2.020
# [epoch: 1, i:  8399] avg mini-batch loss: 1.990
# [epoch: 1, i:  8499] avg mini-batch loss: 1.979
# [epoch: 1, i:  8599] avg mini-batch loss: 1.983
# [epoch: 1, i:  8699] avg mini-batch loss: 1.959
# [epoch: 1, i:  8799] avg mini-batch loss: 1.978
# [epoch: 1, i:  8899] avg mini-batch loss: 1.940
# [epoch: 1, i:  8999] avg mini-batch loss: 2.018
# [epoch: 1, i:  9099] avg mini-batch loss: 1.982
# [epoch: 1, i:  9199] avg mini-batch loss: 2.028
# [epoch: 1, i:  9299] avg mini-batch loss: 1.989
# [epoch: 1, i:  9399] avg mini-batch loss: 1.981
# [epoch: 1, i:  9499] avg mini-batch loss: 1.974
# [epoch: 1, i:  9599] avg mini-batch loss: 1.931
# [epoch: 1, i:  9699] avg mini-batch loss: 2.011
# [epoch: 1, i:  9799] avg mini-batch loss: 1.975
# [epoch: 1, i:  9899] avg mini-batch loss: 2.002
# [epoch: 1, i:  9999] avg mini-batch loss: 1.982
# [epoch: 1, i: 10099] avg mini-batch loss: 1.972
# [epoch: 1, i: 10199] avg mini-batch loss: 2.002
# [epoch: 1, i: 10299] avg mini-batch loss: 2.000
# [epoch: 1, i: 10399] avg mini-batch loss: 1.972
# [epoch: 1, i: 10499] avg mini-batch loss: 1.938
# [epoch: 1, i: 10599] avg mini-batch loss: 1.941
# [epoch: 1, i: 10699] avg mini-batch loss: 1.962
# [epoch: 1, i: 10799] avg mini-batch loss: 1.978
# [epoch: 1, i: 10899] avg mini-batch loss: 2.023
# [epoch: 1, i: 10999] avg mini-batch loss: 1.987
# [epoch: 1, i: 11099] avg mini-batch loss: 1.964
# [epoch: 1, i: 11199] avg mini-batch loss: 2.040
# [epoch: 1, i: 11299] avg mini-batch loss: 1.950
# [epoch: 1, i: 11399] avg mini-batch loss: 2.008
# [epoch: 1, i: 11499] avg mini-batch loss: 1.958
# [epoch: 1, i: 11599] avg mini-batch loss: 2.011
# [epoch: 1, i: 11699] avg mini-batch loss: 1.919
# [epoch: 1, i: 11799] avg mini-batch loss: 2.000
# [epoch: 1, i: 11899] avg mini-batch loss: 1.960
# [epoch: 1, i: 11999] avg mini-batch loss: 2.035
# [epoch: 1, i: 12099] avg mini-batch loss: 1.932
# [epoch: 1, i: 12199] avg mini-batch loss: 2.037
# [epoch: 1, i: 12299] avg mini-batch loss: 1.936
# [epoch: 1, i: 12399] avg mini-batch loss: 2.031
# [epoch: 1, i: 12499] avg mini-batch loss: 1.983
# [epoch: 2, i:    99] avg mini-batch loss: 1.975
# [epoch: 2, i:   199] avg mini-batch loss: 1.988
# [epoch: 2, i:   299] avg mini-batch loss: 1.932
# [epoch: 2, i:   399] avg mini-batch loss: 1.943
# [epoch: 2, i:   499] avg mini-batch loss: 1.987
# [epoch: 2, i:   599] avg mini-batch loss: 2.019
# [epoch: 2, i:   699] avg mini-batch loss: 1.903
# [epoch: 2, i:   799] avg mini-batch loss: 1.963
# [epoch: 2, i:   899] avg mini-batch loss: 1.989
# [epoch: 2, i:   999] avg mini-batch loss: 1.955
# [epoch: 2, i:  1099] avg mini-batch loss: 1.889
# [epoch: 2, i:  1199] avg mini-batch loss: 1.922
# [epoch: 2, i:  1299] avg mini-batch loss: 1.960
# [epoch: 2, i:  1399] avg mini-batch loss: 1.970
# [epoch: 2, i:  1499] avg mini-batch loss: 1.846
# [epoch: 2, i:  1599] avg mini-batch loss: 1.934
# [epoch: 2, i:  1699] avg mini-batch loss: 1.956
# [epoch: 2, i:  1799] avg mini-batch loss: 1.964
# [epoch: 2, i:  1899] avg mini-batch loss: 1.966
# [epoch: 2, i:  1999] avg mini-batch loss: 2.000
# [epoch: 2, i:  2099] avg mini-batch loss: 1.946
# [epoch: 2, i:  2199] avg mini-batch loss: 1.982
# [epoch: 2, i:  2299] avg mini-batch loss: 1.936
# [epoch: 2, i:  2399] avg mini-batch loss: 1.962
# [epoch: 2, i:  2499] avg mini-batch loss: 1.894
# [epoch: 2, i:  2599] avg mini-batch loss: 1.999
# [epoch: 2, i:  2699] avg mini-batch loss: 1.984
# [epoch: 2, i:  2799] avg mini-batch loss: 1.981
# [epoch: 2, i:  2899] avg mini-batch loss: 1.956
# [epoch: 2, i:  2999] avg mini-batch loss: 1.944
# [epoch: 2, i:  3099] avg mini-batch loss: 1.954
# [epoch: 2, i:  3199] avg mini-batch loss: 1.934
# [epoch: 2, i:  3299] avg mini-batch loss: 1.947
# [epoch: 2, i:  3399] avg mini-batch loss: 1.979
# [epoch: 2, i:  3499] avg mini-batch loss: 1.956
# [epoch: 2, i:  3599] avg mini-batch loss: 1.954
# [epoch: 2, i:  3699] avg mini-batch loss: 1.935
# [epoch: 2, i:  3799] avg mini-batch loss: 2.013
# [epoch: 2, i:  3899] avg mini-batch loss: 1.984
# [epoch: 2, i:  3999] avg mini-batch loss: 1.950
# [epoch: 2, i:  4099] avg mini-batch loss: 1.918
# [epoch: 2, i:  4199] avg mini-batch loss: 1.978
# [epoch: 2, i:  4299] avg mini-batch loss: 1.906
# [epoch: 2, i:  4399] avg mini-batch loss: 1.917
# [epoch: 2, i:  4499] avg mini-batch loss: 1.907
# [epoch: 2, i:  4599] avg mini-batch loss: 1.948
# [epoch: 2, i:  4699] avg mini-batch loss: 1.923
# [epoch: 2, i:  4799] avg mini-batch loss: 1.921
# [epoch: 2, i:  4899] avg mini-batch loss: 1.915
# [epoch: 2, i:  4999] avg mini-batch loss: 2.013
# [epoch: 2, i:  5099] avg mini-batch loss: 1.955
# [epoch: 2, i:  5199] avg mini-batch loss: 1.927
# [epoch: 2, i:  5299] avg mini-batch loss: 1.899
# [epoch: 2, i:  5399] avg mini-batch loss: 2.007
# [epoch: 2, i:  5499] avg mini-batch loss: 1.895
# [epoch: 2, i:  5599] avg mini-batch loss: 1.897
# [epoch: 2, i:  5699] avg mini-batch loss: 1.978
# [epoch: 2, i:  5799] avg mini-batch loss: 1.946
# [epoch: 2, i:  5899] avg mini-batch loss: 1.894
# [epoch: 2, i:  5999] avg mini-batch loss: 1.879
# [epoch: 2, i:  6099] avg mini-batch loss: 1.912
# [epoch: 2, i:  6199] avg mini-batch loss: 1.931
# [epoch: 2, i:  6299] avg mini-batch loss: 1.898
# [epoch: 2, i:  6399] avg mini-batch loss: 1.939
# [epoch: 2, i:  6499] avg mini-batch loss: 1.942
# [epoch: 2, i:  6599] avg mini-batch loss: 1.925
# [epoch: 2, i:  6699] avg mini-batch loss: 1.954
# [epoch: 2, i:  6799] avg mini-batch loss: 1.919
# [epoch: 2, i:  6899] avg mini-batch loss: 1.985
# [epoch: 2, i:  6999] avg mini-batch loss: 1.936
# [epoch: 2, i:  7099] avg mini-batch loss: 1.886
# [epoch: 2, i:  7199] avg mini-batch loss: 1.947
# [epoch: 2, i:  7299] avg mini-batch loss: 1.926
# [epoch: 2, i:  7399] avg mini-batch loss: 1.985
# [epoch: 2, i:  7499] avg mini-batch loss: 1.848
# [epoch: 2, i:  7599] avg mini-batch loss: 1.953
# [epoch: 2, i:  7699] avg mini-batch loss: 1.940
# [epoch: 2, i:  7799] avg mini-batch loss: 1.923
# [epoch: 2, i:  7899] avg mini-batch loss: 1.883
# [epoch: 2, i:  7999] avg mini-batch loss: 1.842
# [epoch: 2, i:  8099] avg mini-batch loss: 1.919
# [epoch: 2, i:  8199] avg mini-batch loss: 1.937
# [epoch: 2, i:  8299] avg mini-batch loss: 1.919
# [epoch: 2, i:  8399] avg mini-batch loss: 1.943
# [epoch: 2, i:  8499] avg mini-batch loss: 1.930
# [epoch: 2, i:  8599] avg mini-batch loss: 1.947
# [epoch: 2, i:  8699] avg mini-batch loss: 1.920
# [epoch: 2, i:  8799] avg mini-batch loss: 1.824
# [epoch: 2, i:  8899] avg mini-batch loss: 1.905
# [epoch: 2, i:  8999] avg mini-batch loss: 2.003
# [epoch: 2, i:  9099] avg mini-batch loss: 1.893
# [epoch: 2, i:  9199] avg mini-batch loss: 1.964
# [epoch: 2, i:  9299] avg mini-batch loss: 1.920
# [epoch: 2, i:  9399] avg mini-batch loss: 1.897
# [epoch: 2, i:  9499] avg mini-batch loss: 1.828
# [epoch: 2, i:  9599] avg mini-batch loss: 1.927
# [epoch: 2, i:  9699] avg mini-batch loss: 1.894
# [epoch: 2, i:  9799] avg mini-batch loss: 1.861
# [epoch: 2, i:  9899] avg mini-batch loss: 1.904
# [epoch: 2, i:  9999] avg mini-batch loss: 1.842
# [epoch: 2, i: 10099] avg mini-batch loss: 1.845
# [epoch: 2, i: 10199] avg mini-batch loss: 1.913
# [epoch: 2, i: 10299] avg mini-batch loss: 1.925
# [epoch: 2, i: 10399] avg mini-batch loss: 1.948
# [epoch: 2, i: 10499] avg mini-batch loss: 1.964
# [epoch: 2, i: 10599] avg mini-batch loss: 1.856
# [epoch: 2, i: 10699] avg mini-batch loss: 1.879
# [epoch: 2, i: 10799] avg mini-batch loss: 1.962
# [epoch: 2, i: 10899] avg mini-batch loss: 1.923
# [epoch: 2, i: 10999] avg mini-batch loss: 1.858
# [epoch: 2, i: 11099] avg mini-batch loss: 1.882
# [epoch: 2, i: 11199] avg mini-batch loss: 1.941
# [epoch: 2, i: 11299] avg mini-batch loss: 1.885
# [epoch: 2, i: 11399] avg mini-batch loss: 1.901
# [epoch: 2, i: 11499] avg mini-batch loss: 1.880
# [epoch: 2, i: 11599] avg mini-batch loss: 1.913
# [epoch: 2, i: 11699] avg mini-batch loss: 1.927
# [epoch: 2, i: 11799] avg mini-batch loss: 1.837
# [epoch: 2, i: 11899] avg mini-batch loss: 1.908
# [epoch: 2, i: 11999] avg mini-batch loss: 1.940
# [epoch: 2, i: 12099] avg mini-batch loss: 1.779
# [epoch: 2, i: 12199] avg mini-batch loss: 1.894
# [epoch: 2, i: 12299] avg mini-batch loss: 1.974
# [epoch: 2, i: 12399] avg mini-batch loss: 1.924
# [epoch: 2, i: 12499] avg mini-batch loss: 1.955
# [epoch: 3, i:    99] avg mini-batch loss: 1.899
# [epoch: 3, i:   199] avg mini-batch loss: 1.905
# [epoch: 3, i:   299] avg mini-batch loss: 1.860
# [epoch: 3, i:   399] avg mini-batch loss: 1.871
# [epoch: 3, i:   499] avg mini-batch loss: 1.921
# [epoch: 3, i:   599] avg mini-batch loss: 1.926
# [epoch: 3, i:   699] avg mini-batch loss: 1.908
# [epoch: 3, i:   799] avg mini-batch loss: 1.850
# [epoch: 3, i:   899] avg mini-batch loss: 1.827
# [epoch: 3, i:   999] avg mini-batch loss: 1.883
# [epoch: 3, i:  1099] avg mini-batch loss: 1.934
# [epoch: 3, i:  1199] avg mini-batch loss: 1.902
# [epoch: 3, i:  1299] avg mini-batch loss: 1.891
# [epoch: 3, i:  1399] avg mini-batch loss: 1.907
# [epoch: 3, i:  1499] avg mini-batch loss: 1.842
# [epoch: 3, i:  1599] avg mini-batch loss: 1.942
# [epoch: 3, i:  1699] avg mini-batch loss: 1.961
# [epoch: 3, i:  1799] avg mini-batch loss: 1.862
# [epoch: 3, i:  1899] avg mini-batch loss: 1.965
# [epoch: 3, i:  1999] avg mini-batch loss: 1.802
# [epoch: 3, i:  2099] avg mini-batch loss: 1.930
# [epoch: 3, i:  2199] avg mini-batch loss: 1.917
# [epoch: 3, i:  2299] avg mini-batch loss: 1.870
# [epoch: 3, i:  2399] avg mini-batch loss: 1.901
# [epoch: 3, i:  2499] avg mini-batch loss: 1.853
# [epoch: 3, i:  2599] avg mini-batch loss: 1.894
# [epoch: 3, i:  2699] avg mini-batch loss: 1.874
# [epoch: 3, i:  2799] avg mini-batch loss: 1.944
# [epoch: 3, i:  2899] avg mini-batch loss: 1.975
# [epoch: 3, i:  2999] avg mini-batch loss: 1.909
# [epoch: 3, i:  3099] avg mini-batch loss: 1.818
# [epoch: 3, i:  3199] avg mini-batch loss: 1.842
# [epoch: 3, i:  3299] avg mini-batch loss: 1.873
# [epoch: 3, i:  3399] avg mini-batch loss: 1.860
# [epoch: 3, i:  3499] avg mini-batch loss: 1.948
# [epoch: 3, i:  3599] avg mini-batch loss: 1.891
# [epoch: 3, i:  3699] avg mini-batch loss: 1.881
# [epoch: 3, i:  3799] avg mini-batch loss: 1.851
# [epoch: 3, i:  3899] avg mini-batch loss: 1.884
# [epoch: 3, i:  3999] avg mini-batch loss: 1.901
# [epoch: 3, i:  4099] avg mini-batch loss: 1.805
# [epoch: 3, i:  4199] avg mini-batch loss: 1.853
# [epoch: 3, i:  4299] avg mini-batch loss: 1.799
# [epoch: 3, i:  4399] avg mini-batch loss: 1.918
# [epoch: 3, i:  4499] avg mini-batch loss: 1.874
# [epoch: 3, i:  4599] avg mini-batch loss: 1.861
# [epoch: 3, i:  4699] avg mini-batch loss: 1.932
# [epoch: 3, i:  4799] avg mini-batch loss: 1.900
# [epoch: 3, i:  4899] avg mini-batch loss: 1.904
# [epoch: 3, i:  4999] avg mini-batch loss: 1.927
# [epoch: 3, i:  5099] avg mini-batch loss: 1.942
# [epoch: 3, i:  5199] avg mini-batch loss: 1.852
# [epoch: 3, i:  5299] avg mini-batch loss: 1.844
# [epoch: 3, i:  5399] avg mini-batch loss: 1.899
# [epoch: 3, i:  5499] avg mini-batch loss: 1.869
# [epoch: 3, i:  5599] avg mini-batch loss: 1.834
# [epoch: 3, i:  5699] avg mini-batch loss: 1.828
# [epoch: 3, i:  5799] avg mini-batch loss: 1.944
# [epoch: 3, i:  5899] avg mini-batch loss: 1.832
# [epoch: 3, i:  5999] avg mini-batch loss: 1.850
# [epoch: 3, i:  6099] avg mini-batch loss: 1.858
# [epoch: 3, i:  6199] avg mini-batch loss: 1.877
# [epoch: 3, i:  6299] avg mini-batch loss: 1.905
# [epoch: 3, i:  6399] avg mini-batch loss: 1.877
# [epoch: 3, i:  6499] avg mini-batch loss: 1.809
# [epoch: 3, i:  6599] avg mini-batch loss: 1.868
# [epoch: 3, i:  6699] avg mini-batch loss: 1.885
# [epoch: 3, i:  6799] avg mini-batch loss: 1.935
# [epoch: 3, i:  6899] avg mini-batch loss: 1.829
# [epoch: 3, i:  6999] avg mini-batch loss: 1.943
# [epoch: 3, i:  7099] avg mini-batch loss: 1.851
# [epoch: 3, i:  7199] avg mini-batch loss: 1.876
# [epoch: 3, i:  7299] avg mini-batch loss: 1.783
# [epoch: 3, i:  7399] avg mini-batch loss: 1.883
# [epoch: 3, i:  7499] avg mini-batch loss: 1.891
# [epoch: 3, i:  7599] avg mini-batch loss: 1.870
# [epoch: 3, i:  7699] avg mini-batch loss: 1.852
# [epoch: 3, i:  7799] avg mini-batch loss: 1.923
# [epoch: 3, i:  7899] avg mini-batch loss: 1.935
# [epoch: 3, i:  7999] avg mini-batch loss: 1.867
# [epoch: 3, i:  8099] avg mini-batch loss: 1.836
# [epoch: 3, i:  8199] avg mini-batch loss: 1.854
# [epoch: 3, i:  8299] avg mini-batch loss: 1.930
# [epoch: 3, i:  8399] avg mini-batch loss: 1.851
# [epoch: 3, i:  8499] avg mini-batch loss: 1.791
# [epoch: 3, i:  8599] avg mini-batch loss: 1.935
# [epoch: 3, i:  8699] avg mini-batch loss: 1.851
# [epoch: 3, i:  8799] avg mini-batch loss: 1.785
# [epoch: 3, i:  8899] avg mini-batch loss: 1.853
# [epoch: 3, i:  8999] avg mini-batch loss: 1.823
# [epoch: 3, i:  9099] avg mini-batch loss: 1.828
# [epoch: 3, i:  9199] avg mini-batch loss: 1.855
# [epoch: 3, i:  9299] avg mini-batch loss: 1.869
# [epoch: 3, i:  9399] avg mini-batch loss: 1.844
# [epoch: 3, i:  9499] avg mini-batch loss: 1.865
# [epoch: 3, i:  9599] avg mini-batch loss: 1.847
# [epoch: 3, i:  9699] avg mini-batch loss: 1.884
# [epoch: 3, i:  9799] avg mini-batch loss: 1.840
# [epoch: 3, i:  9899] avg mini-batch loss: 1.865
# [epoch: 3, i:  9999] avg mini-batch loss: 1.865
# [epoch: 3, i: 10099] avg mini-batch loss: 1.777
# [epoch: 3, i: 10199] avg mini-batch loss: 1.892
# [epoch: 3, i: 10299] avg mini-batch loss: 1.801
# [epoch: 3, i: 10399] avg mini-batch loss: 1.825
# [epoch: 3, i: 10499] avg mini-batch loss: 1.844
# [epoch: 3, i: 10599] avg mini-batch loss: 1.868
# [epoch: 3, i: 10699] avg mini-batch loss: 1.819
# [epoch: 3, i: 10799] avg mini-batch loss: 1.904
# [epoch: 3, i: 10899] avg mini-batch loss: 1.874
# [epoch: 3, i: 10999] avg mini-batch loss: 1.915
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 22
#      19 loss = loss_func(outputs, labels)
#      21 # Backward step.
# ---> 22 loss.backward()
#      24 # Optimization step (update the parameters).
#      25 opt.step()
#
# File c:\Users\kavan\anaconda3\envs\COGS118B\lib\site-packages\torch\_tensor.py:492, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     482 if has_torch_function_unary(self):
#     483     return handle_torch_function(
#     484         Tensor.backward,
#     485         (self,),
#    (...)
#     490         inputs=inputs,
#     491     )
# --> 492 torch.autograd.backward(
#     493     self, gradient, retain_graph, create_graph, inputs=inputs
#     494 )
#
# File c:\Users\kavan\anaconda3\envs\COGS118B\lib\site-packages\torch\autograd\__init__.py:251, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     246     retain_graph = create_graph
#     248 # The reason we repeat the same comment below is that
#     249 # some Python versions print out the first line of a multi-line function
#     250 # calls in the traceback and some print out the last line
# --> 251 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     252     tensors,
#     253     grad_tensors_,
#     254     retain_graph,
#     255     create_graph,
#     256     inputs,
#     257     allow_unreachable=True,
#     258     accumulate_grad=True,
#     259 )
#
# KeyboardInterrupt:

# %% [markdown]
# #### Training Loss Curve

# %%
plt.plot(avg_losses)
plt.xlabel('mini-batch index / {}'.format(print_freq))
plt.ylabel('avg. mini-batch loss')
plt.show()

# %% [markdown]
# #### Evaluate on Test Dataset

# %%
# Check several images.
dataiter = iter(testloader)
images, labels = next(dataiter)
imshow(torchvision.utils.make_grid(images))
print('GroundTruth: ', ' '.join('%5s' % classes[labels[j]] for j in range(4)))
outputs = net(images.to(device))
_, predicted = torch.max(outputs, 1)

print('Predicted: ', ' '.join('%5s' % classes[predicted[j]]
                              for j in range(4)))
# Out:
# GroundTruth:    cat  ship  ship plane
# Predicted:    cat   car  ship  ship

# %%
# Get test accuracy.
correct = 0
total = 0
with torch.no_grad():
    for data in testloader:
        images, labels = data
        images, labels = images.to(device), labels.to(device)
        outputs = net(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print('Accuracy of the network on the 10000 test images: %d %%' % (
    100 * correct / total))
# Out:
# Accuracy of the network on the 10000 test images: 50 %

# %%
# Get test accuracy for each class.
class_correct = list(0. for i in range(10))
class_total = list(0. for i in range(10))
with torch.no_grad():
    for data in testloader:
        images, labels = data
        images, labels = images.to(device), labels.to(device)
        outputs = net(images)
        _, predicted = torch.max(outputs, 1)
        c = (predicted == labels).squeeze()
        for i in range(4):
            label = labels[i]
            class_correct[label] += c[i].item()
            class_total[label] += 1

for i in range(10):
    print('Accuracy of %5s : %2d %%' % (
        classes[i], 100 * class_correct[i] / class_total[i]))
# Out:
# Accuracy of plane : 56 %
# Accuracy of   car : 66 %
# Accuracy of  bird : 40 %
# Accuracy of   cat : 29 %
# Accuracy of  deer : 41 %
# Accuracy of   dog : 36 %
# Accuracy of  frog : 52 %
# Accuracy of horse : 57 %
# Accuracy of  ship : 65 %
# Accuracy of truck : 54 %
